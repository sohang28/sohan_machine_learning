# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Social_Network_Ads.csv')
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
df.shape
# Out:
# (400, 5)

# %%
# Assignment: Check duplicates record
df.duplicated().sum() # We have zero duplicated value.
# Out:
# 0

# %% [markdown]
# # Problem statement: We have purchase history of 400 Customers
# # We need to build a ML model to predict that customer will buy the product or not

# %%
# Check assumptions
df.Purchased.unique()
# Out:
# array([0, 1])

# %%
# Check for databalance
df.Purchased.value_counts()
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %% [markdown]
# 0 - not Purchased and 1- Purchased

# %% [markdown]
# ## Check Genderwise Purchase

# %%
sns.countplot(data=df,x='Purchased',hue = 'Gender')
# Out:
# <Axes: xlabel='Purchased', ylabel='count'>

# %% [markdown]
# ## Analysis
# 1- From the above plot we can say that,More than 120 Males as well Females are not purchasing. It can be seen with the value 0(zero) on the x-axis.
#
# 2- And Purchasing count of Males as well as females is between the range of (60-80). It is shown with the value 1 (one) on the x-axis.
